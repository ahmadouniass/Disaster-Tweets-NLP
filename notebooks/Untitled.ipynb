# %%
# !pip install mlflow
# Out:
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/10.6 MB 5.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/10.6 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 15.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ---------------------------------------- 3.3/3.3 MB 19.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 17.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/27.5 MB ? eta -:--:--
#    ------- -------------------------------- 5.2/27.5 MB 26.6 MB/s eta 0:00:01
#    --------------- ------------------------ 10.7/27.5 MB 25.8 MB/s eta 0:00:01
# ...
